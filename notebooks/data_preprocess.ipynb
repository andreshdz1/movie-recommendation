# %%
import pandas as pd

df = pd.read_csv("../data/imdb_top_1000.csv")
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %%
df = df.drop(["Certificate", "Poster_Link", "Overview", "Runtime", "Series_Title", "Gross"], axis = 1)
df.head()
# Out:
#   Released_Year                 Genre  IMDB_Rating  Meta_score  \
# 0          1994                 Drama          9.3        80.0
# 1          1972          Crime, Drama          9.2       100.0
# 2          2008  Action, Crime, Drama          9.0        84.0
# 3          1974          Crime, Drama          9.0        90.0
# 4          1957          Crime, Drama          9.0        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes
# 0  William Sadler      2343110
# 1    Diane Keaton      1620367
# 2   Michael Caine      2303232
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Released_Year  1000 non-null   object
#  1   Genre          1000 non-null   object
#  2   IMDB_Rating    1000 non-null   float64
#  3   Meta_score     843 non-null    float64
#  4   Director       1000 non-null   object
#  5   Star1          1000 non-null   object
#  6   Star2          1000 non-null   object
#  7   Star3          1000 non-null   object
#  8   Star4          1000 non-null   object
#  9   No_of_Votes    1000 non-null   int64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 78.2+ KB

# %%
df.fillna(df.mean, inplace=True)
# Out:
# /var/folders/t8/_zfgsj017k320b_wlgx844gc0000gn/T/ipykernel_80929/3587490214.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '<bound method DataFrame.mean of     Released_Year                     Genre  IMDB_Rating  Meta_score  \
# 0            1994                     Drama          9.3        80.0
# 1            1972              Crime, Drama          9.2       100.0
# 2            2008      Action, Crime, Drama          9.0        84.0
# 3            1974              Crime, Drama          9.0        90.0
# 4            1957              Crime, Drama          9.0        96.0
# ..            ...                       ...          ...         ...
# 995          1961    Comedy, Drama, Romance          7.6        76.0
# 996          1956            Drama, Western          7.6        84.0
# 997          1953       Drama, Romance, War          7.6        85.0
# ...

# %%
df_processed = pd.get_dummies(df)

# %%
df_processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Columns: 4247 entries, IMDB_Rating to Star4_Émile Vallée
# dtypes: bool(4245), float64(1), int64(1)
# memory usage: 4.1 MB

# %%
from sklearn.neighbors import NearestNeighbors

model = NearestNeighbors(n_neighbors=5, metric="cosine")
model.fit(df_processed)
# Out:
# NearestNeighbors(metric='cosine')

# %% [markdown]
# # Testing

# %%
full_movies = pd.read_csv("../data/imdb_top_1000.csv")
movie_name = "The Matrix"

# %%
reference_movie = full_movies[full_movies["Series_Title"] == movie_name]
reference_movie
# Out:
#                                           Poster_Link Series_Title  \
# 14  https://m.media-amazon.com/images/M/MV5BNzQzOT...   The Matrix
#
#    Released_Year Certificate  Runtime           Genre  IMDB_Rating  \
# 14          1999           A  136 min  Action, Sci-Fi          8.7
#
#                                              Overview  Meta_score  \
# 14  When a beautiful stranger leads computer hacke...        73.0
#
#           Director            Star1         Star2               Star3  \
# 14  Lana Wachowski  Lilly Wachowski  Keanu Reeves  Laurence Fishburne
#
#                Star4  No_of_Votes        Gross
# 14  Carrie-Anne Moss      1676426  171,479,930

# %%
index_movie = reference_movie.index.item()
index_movie
# Out:
# 14

# %%
numeric_movie = df_processed.iloc[index_movie]
numeric_movie.values
# Out:
# array([np.float64(8.7), np.int64(1676426), np.False_, ..., np.False_,
#        np.False_, np.False_], dtype=object)

# %%
df_processed.to_csv("../data/numeric_movies.csv", index=False)

# %%
import pickle

# save
with open('model.pkl','wb') as f:
    pickle.dump(model,f)

# %%
model.kneighbors(numeric_movie.values.reshape(1, -1))
# Out:
# /Users/ivanrs/opt/anaconda3/envs/marista/lib/python3.10/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# (array([[0.00000000e+00, 2.36333175e-12, 2.67252886e-12, 2.69828604e-12,
#          2.79409829e-12]]),
#  array([[14,  9,  6, 11,  8]]))

# %%
full_movies.head(15)
# Out:
#                                           Poster_Link  \
# 0   https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1   https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3   https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4   https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 5   https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 6   https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7   https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 8   https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 9   https://m.media-amazon.com/images/M/MV5BMmEzNT...
# 10  https://m.media-amazon.com/images/M/MV5BN2EyZj...
# 11  https://m.media-amazon.com/images/M/MV5BNWIwOD...
# 12  https://m.media-amazon.com/images/M/MV5BOTQ5ND...
# 13  https://m.media-amazon.com/images/M/MV5BZGMxZT...
# 14  https://m.media-amazon.com/images/M/MV5BNzQzOT...
#
#                                          Series_Title Released_Year  \
# ...
